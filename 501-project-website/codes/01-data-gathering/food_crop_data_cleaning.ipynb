# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read the data from the csv file
df1 = pd.read_csv('/Users/sangeetha/Documents/anly-501-project-Sangeetha-238/501-project-website/data/new_data1.csv')
df1.head()
# Out:
#   Domain Code                       Domain  Area Code (M49)  \
# 0          GW  Food systems waste disposal              840
# 1          GW  Food systems waste disposal              840
# 2          GW  Food systems waste disposal              840
# 3          GW  Food systems waste disposal              840
# 4          GW  Food systems waste disposal              840
#
#                        Area  Element Code          Element  Item Code  \
# 0  United States of America          7230  Emissions (N2O)       6988
# 1  United States of America          7230  Emissions (N2O)       6988
# 2  United States of America          7230  Emissions (N2O)       6988
# 3  United States of America          7230  Emissions (N2O)       6988
# 4  United States of America          7230  Emissions (N2O)       6988
#
#                   Item  Year Code  Year        Unit      Value Flag  \
# 0  Domestic wastewater       1990  1990  kilotonnes  10.629803    E
# 1  Domestic wastewater       1991  1991  kilotonnes  10.934600    E
# 2  Domestic wastewater       1992  1992  kilotonnes  11.138956    E
# 3  Domestic wastewater       1993  1993  kilotonnes  11.335046    E
# 4  Domestic wastewater       1994  1994  kilotonnes  11.754348    E
#
#    Flag Description
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %%
#remove unwanted columns
df1.drop(['Domain Code','Area Code (M49)','Element Code','Item Code','Year Code','Flag Description','Unit','Flag'],axis=1,inplace=True)

# %%
#check for null values
df1.isnull().sum()
# Out:
# Domain     0
# Area       0
# Element    0
# Item       0
# Year       0
# Value      0
# dtype: int64

# %%
#import data from the csv file
df2 = pd.read_csv('/Users/sangeetha/Documents/anly-501-project-Sangeetha-238/501-project-website/data/new_data2.csv')
df2.head()
# Out:
#   Domain Code                   Domain  Area Code (M49)  \
# 0          GB  Burning - Crop Residues              840
# 1          GB  Burning - Crop Residues              840
# 2          GB  Burning - Crop Residues              840
# 3          GB  Burning - Crop Residues              840
# 4          GB  Burning - Crop Residues              840
#
#                        Area  Element Code                      Element  \
# 0  United States of America          7245  Biomass burned (dry matter)
# 1  United States of America          7230              Emissions (N2O)
# 2  United States of America          7225              Emissions (CH4)
# 3  United States of America          7245  Biomass burned (dry matter)
# 4  United States of America          7230              Emissions (N2O)
#
#    Item Code (CPC)          Item  Year Code  Year  Source Code      Source  \
# 0              112  Maize (corn)       1961  1961         3050  FAO TIER 1
# 1              112  Maize (corn)       1961  1961         3050  FAO TIER 1
# 2              112  Maize (corn)       1961  1961         3050  FAO TIER 1
# 3              112  Maize (corn)       1962  1962         3050  FAO TIER 1
# 4              112  Maize (corn)       1962  1962         3050  FAO TIER 1
#
#          Unit         Value Flag Flag Description  Note
# 0      tonnes  2.332301e+07    E  Estimated value   NaN
# 1  kilotonnes  1.632600e+00    E  Estimated value   NaN
# 2  kilotonnes  6.297210e+01    E  Estimated value   NaN
# 3      tonnes  2.255101e+07    E  Estimated value   NaN
# 4  kilotonnes  1.578600e+00    E  Estimated value   NaN

# %%
#remove unwanted columns
df2.drop(['Domain Code','Area Code (M49)','Element Code','Year Code','Flag Description','Unit','Source Code','Source','Item Code (CPC)','Note','Flag'],axis=1,inplace=True)

# %%
#check for null values
df1.isnull().sum()
# Out:
# Domain     0
# Area       0
# Element    0
# Item       0
# Year       0
# Value      0
# dtype: int64

# %%
#merge the two dataframes
df = pd.concat([df1,df2],axis=0)
df.head()
# Out:
#                         Domain                      Area          Element  \
# 0  Food systems waste disposal  United States of America  Emissions (N2O)
# 1  Food systems waste disposal  United States of America  Emissions (N2O)
# 2  Food systems waste disposal  United States of America  Emissions (N2O)
# 3  Food systems waste disposal  United States of America  Emissions (N2O)
# 4  Food systems waste disposal  United States of America  Emissions (N2O)
#
#                   Item  Year      Value
# 0  Domestic wastewater  1990  10.629803
# 1  Domestic wastewater  1991  10.934600
# 2  Domestic wastewater  1992  11.138956
# 3  Domestic wastewater  1993  11.335046
# 4  Domestic wastewater  1994  11.754348

# %%
#save df into a csv file
df.to_csv('/Users/sangeetha/Documents/anly-501-project-Sangeetha-238/501-project-website/data/food_crop_data.csv', index=False)
